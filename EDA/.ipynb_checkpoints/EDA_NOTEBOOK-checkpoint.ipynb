# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
sys.path.append(os.path.abspath(".."))
from SQL.database import DatabaseConnection
from EDA.visualizations import Visualizations
from tqdm.notebook import tqdm

db = DatabaseConnection()
db.connect()
# Out:
# ✓ Conexión exitosa a MySQL con SQLAlchemy
# True

# %%
# Obtener datos para análisis (ejemplo)
queries = [
    ("student_info", "SELECT * FROM student_info"),
    ("student_registration", "SELECT * FROM student_registration"),
    ("student_vle", "SELECT * FROM student_vle"),
    ("assessments", "SELECT * FROM assessments"),
    ("student_assessment", "SELECT * FROM student_assessment"),
]

dataframes = {}

for name, query in tqdm(queries, desc="Cargando tablas desde MySQL", unit="tabla"):
    print(f"Cargando: {name}")
    dataframes[name] = pd.read_sql(query, db.connection)

# Extraer
student_info = dataframes["student_info"]
student_registration = dataframes["student_registration"]
student_vle = dataframes["student_vle"]
assessments = dataframes["assessments"]
student_assessment = dataframes["student_assessment"]
# Out:
# Cargando tablas desde MySQL:   0%|          | 0/5 [00:00<?, ?tabla/s]
# Cargando: student_info
# Cargando: student_registration
# Cargando: student_vle
# Cargando: assessments
# Cargando: student_assessment

# %%
# -----------------------------------------
# Estadística Descriptiva (por cada tabla)
# -----------------------------------------
for name, df in dataframes.items():
    print(f"\n=== Análisis Exploratorio: {name.upper()} ===")

    # Variables numéricas
    numeric_df = df.select_dtypes(include="number")
    if not numeric_df.empty:
        print("\nEstadísticas numéricas:")
        print(numeric_df.describe().round(2))

        print("\nMatriz de correlación:")
        print(numeric_df.corr().round(2))

        Visualizations.print_strong_correlations(numeric_df)

        # Descomenta si deseas ver el heatmap visual
        Visualizations.plot_correlation_heatmap(numeric_df, title=f"Matriz de Correlación: {name}")

    # Variables categóricas
    cat_cols = df.select_dtypes(include="object").columns
    if not cat_cols.empty:
        print("\nEstadísticas categóricas:")
        for col in cat_cols:
            print(f"\n{col} (top 5):")
            print(df[col].value_counts().head(5))

if not cat_cols.empty:
    print("\nEstadísticas categóricas:")
    for col in cat_cols:
        print(f"\n{col} (top 5):")
        print(df[col].value_counts().head(5))
# Out:
# === Análisis Exploratorio: STUDENT_INFO ===
#
# Estadísticas numéricas:
#        id_student  gender_ordinal  region_ordinal  education_ordinal  \
# count    32593.00        32593.00        32593.00           32593.00
# mean    706687.67            1.45            6.66               2.31
# std     549167.31            0.50            3.97               0.77
# min       3733.00            1.00            1.00               1.00
# 25%     508573.00            1.00            3.00               2.00
# 50%     590310.00            1.00            6.00               2.00
# 75%     644453.00            2.00           10.00               3.00
# max    2716795.00            2.00           13.00               5.00
#
#        imd_band_ordinal  age_band_ordinal  num_of_prev_attempts  \
# count          31482.00          32593.00              32593.00
# mean               5.56              2.70                  0.16
# std                2.89              0.47                  0.48
# min                1.00              1.00                  0.00
# 25%                3.00              2.00                  0.00
# 50%                6.00              3.00                  0.00
# 75%                8.00              3.00                  0.00
# max               10.00              3.00                  6.00
#
#        studied_credits  final_result_ordinal
# count         32593.00              32593.00
# mean             79.76                  2.02
# std              41.07                  0.98
# min              30.00                  1.00
# 25%              60.00                  1.00
# 50%              60.00                  2.00
# 75%             120.00                  3.00
# max             655.00                  4.00
#
# Matriz de correlación:
#                       id_student  gender_ordinal  region_ordinal  \
# id_student                  1.00           -0.00           -0.01
# gender_ordinal             -0.00            1.00            0.02
# region_ordinal             -0.01            0.02            1.00
# education_ordinal          -0.04            0.06            0.05
# imd_band_ordinal           -0.01            0.04            0.03
# age_band_ordinal           -0.20           -0.02           -0.00
# num_of_prev_attempts        0.01            0.03           -0.00
# studied_credits            -0.00           -0.02            0.03
# final_result_ordinal        0.00           -0.01           -0.01
#
#                       education_ordinal  imd_band_ordinal  age_band_ordinal  \
# id_student                        -0.04             -0.01             -0.20
# gender_ordinal                     0.06              0.04             -0.02
# region_ordinal                     0.05              0.03             -0.00
# education_ordinal                  1.00              0.05              0.07
# imd_band_ordinal                   0.05              1.00              0.04
# age_band_ordinal                   0.07              0.04              1.00
# num_of_prev_attempts               0.04              0.02             -0.01
# studied_credits                   -0.02              0.01              0.07
# final_result_ordinal               0.01              0.01             -0.00
#
#                       num_of_prev_attempts  studied_credits  \
# id_student                            0.01            -0.00
# gender_ordinal                        0.03            -0.02
# region_ordinal                       -0.00             0.03
# education_ordinal                     0.04            -0.02
# imd_band_ordinal                      0.02             0.01
# age_band_ordinal                     -0.01             0.07
# num_of_prev_attempts                  1.00             0.18
# studied_credits                       0.18             1.00
# final_result_ordinal                  0.03            -0.00
#
#                       final_result_ordinal
# id_student                            0.00
# gender_ordinal                       -0.01
# region_ordinal                       -0.01
# education_ordinal                     0.01
# imd_band_ordinal                      0.01
# age_band_ordinal                     -0.00
# num_of_prev_attempts                  0.03
# studied_credits                      -0.00
# final_result_ordinal                  1.00
#
# Correlaciones fuertes (> ±0.3):
# Estadísticas categóricas:
#
# code_module (top 5):
# code_module
# BBB    7909
# FFF    7762
# DDD    6272
# CCC    4434
# EEE    2934
# Name: count, dtype: int64
#
# code_presentation (top 5):
# code_presentation
# 2014J    11260
# 2013J     8845
# 2014B     7804
# 2013B     4684
# Name: count, dtype: int64
#
# gender (top 5):
# gender
# M    17875
# F    14718
# Name: count, dtype: int64
#
# region (top 5):
# region
# Scotland                3446
# East Anglian Region     3340
# London Region           3216
# South Region            3092
# North Western Region    2906
# Name: count, dtype: int64
#
# highest_education (top 5):
# highest_education
# A Level or Equivalent          14045
# Lower Than A Level             13158
# HE Qualification                4730
# No Formal quals                  347
# Post Graduate Qualification      313
# Name: count, dtype: int64
#
# imd_band (top 5):
# imd_band
# 20-30%    3654
# 30-40%    3539
# 10-20     3516
# 0-10%     3311
# 40-50%    3256
# Name: count, dtype: int64
#
# age_band (top 5):
# age_band
# 0-35     22944
# 35-55     9433
# 55<=       216
# Name: count, dtype: int64
#
# disability (top 5):
# disability
# No     29429
# Yes     3164
# Name: count, dtype: int64
#
# disability_ordinal (top 5):
# Series([], Name: count, dtype: int64)
#
# final_result (top 5):
# final_result
# Pass           12361
# Withdrawn      10156
# Fail            7052
# Distinction     3024
# Name: count, dtype: int64
#
# === Análisis Exploratorio: STUDENT_REGISTRATION ===
#
# Estadísticas numéricas:
#        id_student  date_registration  date_unregistration
# count    32593.00           32548.00             10072.00
# mean    706687.67             -69.41                49.76
# std     549167.31              49.26                82.46
# min       3733.00            -322.00              -365.00
# 25%     508573.00            -100.00                -2.00
# 50%     590310.00             -57.00                27.00
# 75%     644453.00             -29.00               109.00
# max    2716795.00             167.00               444.00
#
# Matriz de correlación:
#                      id_student  date_registration  date_unregistration
# id_student                 1.00               0.01                 0.01
# date_registration          0.01               1.00                 0.25
# date_unregistration        0.01               0.25                 1.00
#
# Correlaciones fuertes (> ±0.3):
# Estadísticas categóricas:
#
# code_module (top 5):
# code_module
# BBB    7909
# FFF    7762
# DDD    6272
# CCC    4434
# EEE    2934
# Name: count, dtype: int64
#
# code_presentation (top 5):
# code_presentation
# 2014J    11260
# 2013J     8845
# 2014B     7804
# 2013B     4684
# Name: count, dtype: int64
#
# === Análisis Exploratorio: STUDENT_VLE ===
#
# Estadísticas numéricas:
#        id_student     id_site        date   sum_click
# count  8459320.00  8459320.00  8459320.00  8459320.00
# mean    733239.88   735166.06       93.94        4.68
# std     584696.56   130790.74       75.98       10.95
# min       6516.00   526721.00      -25.00        1.00
# 25%     505767.00   673519.00       24.00        1.00
# 50%     587550.00   730035.00       85.00        2.00
# 75%     645997.00   832760.00      155.00        4.00
# max    2698588.00  1049562.00      269.00     6977.00
#
# Matriz de correlación:
#             id_student  id_site  date  sum_click
# id_student        1.00     0.01  0.00       0.00
# id_site           0.01     1.00  0.06       0.02
# date              0.00     0.06  1.00       0.03
# sum_click         0.00     0.02  0.03       1.00
#
# Correlaciones fuertes (> ±0.3):
# Estadísticas categóricas:
#
# code_module (top 5):
# code_module
# FFF    3248703
# DDD    1866156
# BBB    1139085
# CCC     884889
# EEE     758220
# Name: count, dtype: int64
#
# code_presentation (top 5):
# code_presentation
# 2014J    2802894
# 2013J    2412445
# 2014B    1706584
# 2013B    1537397
# Name: count, dtype: int64
#
# === Análisis Exploratorio: ASSESSMENTS ===
#
# Estadísticas numéricas:
#        id_assessment  assessment_type_ordinal    date  weight
# count         206.00                   206.00  195.00  206.00
# mean        26473.98                     1.85  145.01   20.84
# std         10098.63                     0.93   76.00   30.39
# min          1752.00                     1.00   12.00    0.00
# 25%         15023.25                     1.00   71.00    0.00
# 50%         25364.50                     1.00  152.00   12.00
# 75%         34891.75                     3.00  222.00   24.25
# max         40088.00                     3.00  261.00  100.00
#
# Matriz de correlación:
#                          id_assessment  assessment_type_ordinal  date  weight
# id_assessment                     1.00                     0.25  0.37   -0.09
# assessment_type_ordinal           0.25                     1.00  0.52   -0.19
# date                              0.37                     0.52  1.00    0.19
# weight                           -0.09                    -0.19  0.19    1.00
#
# Correlaciones fuertes (> ±0.3):
# assessment_type_ordinal ↔ date = 0.52
# id_assessment ↔ date = 0.37
# Estadísticas categóricas:
#
# code_module (top 5):
# code_module
# FFF    52
# BBB    42
# DDD    35
# GGG    30
# CCC    20
# Name: count, dtype: int64
#
# code_presentation (top 5):
# code_presentation
# 2014J    57
# 2014B    57
# 2013J    53
# 2013B    39
# Name: count, dtype: int64
#
# assessment_type (top 5):
# assessment_type
# TMA     106
# CMA      76
# Exam     24
# Name: count, dtype: int64
#
# === Análisis Exploratorio: STUDENT_ASSESSMENT ===
#
# Estadísticas numéricas:
#        id_assessment  id_student  date_submitted  is_banked     score
# count      173912.00   173912.00       173912.00  173912.00  173739.0
# mean        26553.80   705150.72          116.03       0.01      75.8
# std          8829.78   552395.19           71.48       0.10      18.8
# min          1752.00     6516.00          -11.00       0.00       0.0
# 25%         15022.00   504429.00           51.00       0.00      65.0
# 50%         25359.00   585208.00          116.00       0.00      80.0
# 75%         34883.00   634498.00          173.00       0.00      90.0
# max         37443.00  2698588.00          608.00       1.00     100.0
#
# Matriz de correlación:
#                 id_assessment  id_student  date_submitted  is_banked  score
# id_assessment            1.00       -0.02            0.14      -0.01   0.07
# id_student              -0.02        1.00           -0.01       0.00   0.02
# date_submitted           0.14       -0.01            1.00      -0.17  -0.03
# is_banked               -0.01        0.00           -0.17       1.00  -0.01
# score                    0.07        0.02           -0.03      -0.01   1.00
#
# Correlaciones fuertes (> ±0.3):

# %%
# --- Analisis Student Info ---
confusion_matrix = pd.crosstab(student_info['gender'], student_info['final_result'])
Visualizations.plot_confusion_matrix(confusion_matrix)
"""
Muestra una matriz de confusión entre género y resultado final.
Útil para detectar posibles brechas de género en el rendimiento académico.
"""
# Out:
# '\nMuestra una matriz de confusión entre género y resultado final.\nÚtil para detectar posibles brechas de género en el rendimiento académico.\n'

# %%
numeric_cols = ['num_of_prev_attempts', 'studied_credits']
corr_matrix = student_info[numeric_cols].corr()
Visualizations.plot_correlation_matrix(corr_matrix)
"""
Muestra una matriz de correlación entre variables numéricas.
Útil para descubrir relaciones lineales entre variables como intentos previos y créditos estudiados.
"""
# Out:
# '\nMuestra una matriz de correlación entre variables numéricas.\nÚtil para descubrir relaciones lineales entre variables como intentos previos y créditos estudiados.\n'

# %%
Visualizations.plot_boxplot(student_info, 'num_of_prev_attempts', 'final_result')
"""
Muestra un boxplot de una variable numérica segmentada por una variable categórica.
Útil para visualizar la distribución, la mediana y los outliers en diferentes grupos.
"""
# Out:
# '\nMuestra un boxplot de una variable numérica segmentada por una variable categórica.\nÚtil para visualizar la distribución, la mediana y los outliers en diferentes grupos.\n'

# %%
Visualizations.plot_histogram(student_info, 'studied_credits')
"""
Muestra un histograma de una variable numérica.
Útil para comprender la distribución de la variable (asimetría, sesgo, normalidad).
"""
# Out:
# '\nMuestra un histograma de una variable numérica.\nÚtil para comprender la distribución de la variable (asimetría, sesgo, normalidad).\n'

# %%
Visualizations.plot_scatter(student_info, 'num_of_prev_attempts', 'studied_credits')
"""
Muestra un scatter plot (diagrama de dispersión) entre dos variables numéricas.
Útil para detectar patrones, correlaciones o relaciones no lineales entre variables.
"""
# Out:
# '\nMuestra un scatter plot (diagrama de dispersión) entre dos variables numéricas.\nÚtil para detectar patrones, correlaciones o relaciones no lineales entre variables.\n'

# %%
# Segmentación sociodemográfica
Visualizations.plot_boxplot(student_info, 'studied_credits', 'age_band')

# %%
Visualizations.plot_boxplot(student_info, 'studied_credits', 'imd_band')

# %%
# --- Analisis Student Registration ---
Visualizations.plot_registration_status_distribution(student_registration)
"""
Muestra la distribución de las puntuaciones obtenidas en los assessments.
Útil para analizar el rendimiento de los estudiantes en las diferentes evaluaciones.
"""
# Out:
# '\nMuestra la distribución de las puntuaciones obtenidas en los assessments.\nÚtil para analizar el rendimiento de los estudiantes en las diferentes evaluaciones.\n'

# %%
# --- Analisis Assessments ---
Visualizations.plot_assessment_type_distribution(assessments)

# %%
# --- Analisis Student Assessment ---
Visualizations.plot_assessment_score_distribution(student_assessment)

# %%
# Ejecuta un ANOVA unidireccional para comparar medias entre grupos.
# ANOVA: ¿hay diferencias en créditos estudiados entre bandas de edad?
Visualizations.run_anova(student_info, 'studied_credits', 'age_band')
# Out:
# --- ANOVA: studied_credits by age_band ---
# F-statistic: 83.4006
# P-value: < 0.001
# Diferencias significativas entre al menos un par de grupos.

# %%
Visualizations.run_anova(student_info, 'studied_credits', 'final_result')
# Out:
# --- ANOVA: studied_credits by final_result ---
# F-statistic: 420.9763
# P-value: < 0.001
# Diferencias significativas entre al menos un par de grupos.

# %%
db.disconnect()
